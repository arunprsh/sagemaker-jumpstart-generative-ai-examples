# %% [markdown]
# ## Stable Diffusion (Text to Image) - Finetune with cat images (limited data)

# %% [markdown]
# #### Imports

# %%
from sagemaker.jumpstart.notebook_utils import list_jumpstart_models
from sagemaker.utils import name_from_base
from sagemaker.estimator import Estimator
from sagemaker import get_execution_role
from sagemaker import hyperparameters
from sagemaker import script_uris
from sagemaker import image_uris
from sagemaker import model_uris
import matplotlib.pyplot as plt
import numpy as np
import sagemaker
import datetime
import logging
import boto3
import json

# %% [markdown]
# ##### Setup logging

# %%
logger = logging.getLogger('sagemaker')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())

# %% [markdown]
# ##### Log versions of dependencies

# %%
logger.info(f'[Using SageMaker version: {sagemaker.__version__}]')
# Out:
# [Using SageMaker version: 2.120.0]

# %% [markdown]
# #### I. Setup essentials

# %%
ROLE = get_execution_role()
REGION = boto3.Session().region_name
session = sagemaker.Session()
logger.info(f'Region: {REGION}')
# Out:
# Region: us-east-1

# %% [markdown]
# ##### List all models from SageMaker JumpStart hub

# %%
models = list_jumpstart_models()
len(models)
# Out:
# 524

# %%
FILTER = 'task == txt2img'
txt2img_models = list_jumpstart_models(filter=FILTER)
txt2img_models
# Out:
# ['model-txt2img-stabilityai-stable-diffusion-v1-4',
#  'model-txt2img-stabilityai-stable-diffusion-v1-4-fp16',
#  'model-txt2img-stabilityai-stable-diffusion-v2',
#  'model-txt2img-stabilityai-stable-diffusion-v2-1-base',
#  'model-txt2img-stabilityai-stable-diffusion-v2-fp16']

# %%
MODEL_ID = 'model-txt2img-stabilityai-stable-diffusion-v2-1-base'
MODEL_VERSION = '*'  # latest
SCOPE = 'training'
TRAIN_INSTANCE_TYPE = 'ml.g4dn.2xlarge'

# %% [markdown]
# #### II. Retrieve training artifacts

# %%
train_image_uri = image_uris.retrieve(region=REGION, 
                                      framework=None,
                                      model_id=MODEL_ID, 
                                      model_version=MODEL_VERSION, 
                                      image_scope=SCOPE, 
                                      instance_type=TRAIN_INSTANCE_TYPE)
logger.info(f'Training image URI: {train_image_uri}')
# Out:
# image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# Training image URI: 763104351884.dkr.ecr.us-east-1.amazonaws.com/huggingface-pytorch-training:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04

# %%
train_source_uri = script_uris.retrieve(model_id=MODEL_ID, 
                                        model_version=MODEL_VERSION, 
                                        script_scope=SCOPE)
logger.info(f'Training source URI: {train_source_uri}')
# Out:
# Training source URI: s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/transfer_learning/txt2img/v1.0.0/sourcedir.tar.gz

# %%
train_model_uri = model_uris.retrieve(model_id=MODEL_ID, 
                                      model_version=MODEL_VERSION, 
                                      model_scope=SCOPE)
logger.info(f'Training model URI: {train_model_uri}')
# Out:
# Training model URI: s3://jumpstart-cache-prod-us-east-1/stabilityai-training/train-model-txt2img-stabilityai-stable-diffusion-v2-1-base.tar.gz

# %% [markdown]
# ##### Setup data locations

# %%
DEFAULT_BUCKET = session.default_bucket()
logger.info(f'Default bucket = {DEFAULT_BUCKET}')
# Out:
# Default bucket = sagemaker-us-east-1-119174016168

# %%
TRAIN_DATA_INPUT_PREFIX = 'js-input/cats/'

# %%
TRAIN_DATA_INPUT_S3_PATH = f's3://{DEFAULT_BUCKET}/{TRAIN_DATA_INPUT_PREFIX}'
logger.info(f'Training data input S3 location => {TRAIN_DATA_INPUT_S3_PATH}')
# Out:
# Training data input S3 location => s3://sagemaker-us-east-1-119174016168/js-input/cats/

# %% [markdown]
# #### III. Copy dataset for fine-tuning from local to S3

# %%
# !rm -rf ./data/.ipynb_checkpoints/

# %%
# !aws s3 cp ./data {TRAIN_DATA_INPUT_S3_PATH} --recursive
# Out:
# upload: data/dataset_info.json to s3://sagemaker-us-east-1-119174016168/js-input/cats/dataset_info.json
# upload: data/riobugger2.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger2.jpeg
# upload: data/riobugger4.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger4.jpeg
# upload: data/riobugger6.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger6.jpeg
# upload: data/riobugger3.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger3.jpeg
# upload: data/riobugger8.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger8.jpeg
# upload: data/riobugger5.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger5.jpeg
# upload: data/riobugger1.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger1.jpeg
# upload: data/riobugger7.jpeg to s3://sagemaker-us-east-1-119174016168/js-input/cats/riobugger7.jpeg

# %%
TRAIN_DATA_OUTPUT_PREFIX = 'js-output'
TRAIN_DATA_OUTPUT_S3_PATH = f's3://{DEFAULT_BUCKET}/{TRAIN_DATA_OUTPUT_PREFIX}'
logger.info(f'Training output S3 location => {TRAIN_DATA_OUTPUT_S3_PATH}')
# Out:
# Training output S3 location => s3://sagemaker-us-east-1-119174016168/js-output

# %% [markdown]
# #### IV. Access and update default hyperparams

# %%
hyperparams = hyperparameters.retrieve_default(model_id=MODEL_ID, 
                                                   model_version=MODEL_VERSION)
hyperparams
# Out:
# {'epochs': '20',
#  'max_steps': 'None',
#  'batch_size': '1',
#  'with_prior_preservation': 'False',
#  'num_class_images': '100',
#  'learning_rate': '2e-06',
#  'prior_loss_weight': '1.0',
#  'center_crop': 'False',
#  'lr_scheduler': 'constant',
#  'adam_weight_decay': '0.01',
#  'adam_beta1': '0.9',
#  'adam_beta2': '0.999',
#  'adam_epsilon': '1e-08',
#  'gradient_accumulation_steps': '1',
#  'max_grad_norm': '1.0',
#  'seed': '0'}

# %% [markdown]
# You can also override these hyperparams

# %%
hyperparams['max_steps'] = '400'
hyperparams['seed'] = '123'
hyperparams
# Out:
# {'epochs': '20',
#  'max_steps': '400',
#  'batch_size': '1',
#  'with_prior_preservation': 'False',
#  'num_class_images': '100',
#  'learning_rate': '2e-06',
#  'prior_loss_weight': '1.0',
#  'center_crop': 'False',
#  'lr_scheduler': 'constant',
#  'adam_weight_decay': '0.01',
#  'adam_beta1': '0.9',
#  'adam_beta2': '0.999',
#  'adam_epsilon': '1e-08',
#  'gradient_accumulation_steps': '1',
#  'max_grad_norm': '1.0',
#  'seed': '123'}

# %% [markdown]
# #### V. Finetune Stable Diffusion model

# %%
model_prefix = name_from_base(f'js-{MODEL_ID}-')
training_job_name = f'{model_prefix}-finetuning'
logger.info(f'Train job name => {training_job_name}')
# Out:
# Train job name => js-model-txt2img-stabilityai-stable-dif-2023-02-14-17-38-33-736-finetuning

# %%
MAX_RUN = 360000

# %%
estimator = Estimator(role=ROLE, 
                      image_uri=train_image_uri, 
                      source_dir=train_source_uri, 
                      model_uri=train_model_uri, 
                      entry_point='transfer_learning.py', 
                      instance_count=1, 
                      instance_type=TRAIN_INSTANCE_TYPE, 
                      max_run=MAX_RUN, 
                      hyperparameters=hyperparams, 
                      output_path=TRAIN_DATA_OUTPUT_S3_PATH, 
                      base_job_name=training_job_name)

# %%
# %%time

estimator.fit({'training': TRAIN_DATA_INPUT_S3_PATH}, logs=False)
# Out:
# Defaulting to the only supported framework/algorithm version: latest.
# Ignoring unnecessary instance type: None.
# Creating training-job with name: js-model-txt2img-stabilityai-stable-dif-2023-02-14-17-38-39-296
# train request: {
#     "AlgorithmSpecification": {
#         "TrainingInputMode": "File",
#         "TrainingImage": "763104351884.dkr.ecr.us-east-1.amazonaws.com/huggingface-pytorch-training:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04"
#     },
#     "OutputDataConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-119174016168/js-output"
#     },
#     "TrainingJobName": "js-model-txt2img-stabilityai-stable-dif-2023-02-14-17-38-39-296",
#     "StoppingCondition": {
#         "MaxRuntimeInSeconds": 360000
#     },
#     "ResourceConfig": {
#         "VolumeSizeInGB": 30,
#         "InstanceCount": 1,
#         "InstanceType": "ml.g4dn.2xlarge"
#     },
#     "RoleArn": "arn:aws:iam::119174016168:role/service-role/AmazonSageMaker-ExecutionRole-20211014T093628",
#     "InputDataConfig": [
#         {
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://sagemaker-us-east-1-119174016168/js-input/cats/",
#                     "S3DataDistributionType": "FullyReplicated"
#                 }
#             },
#             "ChannelName": "training"
#         },
#         {
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://jumpstart-cache-prod-us-east-1/stabilityai-training/train-model-txt2img-stabilityai-stable-diffusion-v2-1-base.tar.gz",
#                     "S3DataDistributionType": "FullyReplicated"
#                 }
#             },
#             "ContentType": "application/x-sagemaker-model",
#             "InputMode": "File",
#             "ChannelName": "model"
#         }
#     ],
#     "HyperParameters": {
#         "epochs": "\"20\"",
#         "max_steps": "\"400\"",
#         "batch_size": "\"1\"",
#         "with_prior_preservation": "\"False\"",
#         "num_class_images": "\"100\"",
#         "learning_rate": "\"2e-06\"",
#         "prior_loss_weight": "\"1.0\"",
#         "center_crop": "\"False\"",
#         "lr_scheduler": "\"constant\"",
#         "adam_weight_decay": "\"0.01\"",
#         "adam_beta1": "\"0.9\"",
#         "adam_beta2": "\"0.999\"",
#         "adam_epsilon": "\"1e-08\"",
#         "gradient_accumulation_steps": "\"1\"",
#         "max_grad_norm": "\"1.0\"",
#         "seed": "\"123\"",
#         "sagemaker_submit_directory": "\"s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/transfer_learning/txt2img/v1.0.0/sourcedir.tar.gz\"",
#         "sagemaker_program": "\"transfer_learning.py\"",
#         "sagemaker_container_log_level": "20",
#         "sagemaker_job_name": "\"js-model-txt2img-stabilityai-stable-dif-2023-02-14-17-38-39-296\"",
#         "sagemaker_region": "\"us-east-1\""
#     },
#     "Tags": [
#         {
#             "Key": "aws-jumpstart-training-model-uri",
#             "Value": "s3://jumpstart-cache-prod-us-east-1/stabilityai-training/train-model-txt2img-stabilityai-stable-diffusion-v2-1-base.tar.gz"
#         },
#         {
#             "Key": "aws-jumpstart-training-script-uri",
#             "Value": "s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/transfer_learning/txt2img/v1.0.0/sourcedir.tar.gz"
#         }
#     ],
#     "DebugHookConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-119174016168/js-output",
#         "CollectionConfigurations": []
#     },
#     "ProfilerRuleConfigurations": [
#         {
#             "RuleConfigurationName": "ProfilerReport-1676396319",
#             "RuleEvaluatorImage": "503895931360.dkr.ecr.us-east-1.amazonaws.com/sagemaker-debugger-rules:latest",
#             "RuleParameters": {
#                 "rule_to_invoke": "ProfilerReport"
#             }
#         }
#     ],
#     "ProfilerConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-119174016168/js-output"
#     }
# }
# 2023-02-14 17:38:39 Starting - Starting the training job...
# 2023-02-14 17:38:56 Starting - Preparing the instances for training..............
# 2023-02-14 17:40:11 Downloading - Downloading input data................................
# 2023-02-14 17:43:02 Training - Downloading the training image.....
# 2023-02-14 17:43:32 Training - Training image download completed. Training in progress.........................................................................................................................................................
# 2023-02-14 17:56:22 Uploading - Uploading generated training model....................................................................................................................
# 2023-02-14 18:06:16 Completed - Training job completed
# CPU times: user 1.52 s, sys: 158 ms, total: 1.68 s
# Wall time: 27min 37s

# %% [markdown]
# #### VI. Deploy fine-tuned model as a SageMaker endpoint

# %% [markdown]
# ##### Retrieve artifacts for inference

# %%
SCOPE = 'inference'
INFERENCE_INSTANCE_TYPE = 'ml.g4dn.2xlarge'  # prefered

# %%
deploy_image_uri = image_uris.retrieve(region=REGION, 
                                       framework=None,  
                                       image_scope=SCOPE, 
                                       model_id=MODEL_ID, 
                                       model_version=MODEL_VERSION, 
                                       instance_type=INFERENCE_INSTANCE_TYPE)
logger.info(f'Deploy image URI => {deploy_image_uri}')
# Out:
# Deploy image URI => 763104351884.dkr.ecr.us-east-1.amazonaws.com/huggingface-pytorch-inference:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04

# %%
deploy_source_uri = script_uris.retrieve(model_id=MODEL_ID, 
                                         model_version=MODEL_VERSION, 
                                         script_scope=SCOPE)
logger.info(f'Deploy source URI => {deploy_source_uri}')
# Out:
# Deploy source URI => s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/inference/txt2img/v1.2.1/sourcedir.tar.gz

# %%
current_time = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
endpoint_name = f'js-ep-{current_time}'
endpoint_name
# Out:
# 'js-ep-20230214180617'

# %%
# %%time

predictor = estimator.deploy(initial_instance_count=1, 
                             instance_type=INFERENCE_INSTANCE_TYPE, 
                             entry_point='inference.py', 
                             image_uri=deploy_image_uri, 
                             source_dir=deploy_source_uri, 
                             endpoint_name=endpoint_name)
# Out:
# Creating model with name: sagemaker-jumpstart-2023-02-14-18-06-17-408
# CreateModel request: {
#     "ModelName": "sagemaker-jumpstart-2023-02-14-18-06-17-408",
#     "ExecutionRoleArn": "arn:aws:iam::119174016168:role/service-role/AmazonSageMaker-ExecutionRole-20211014T093628",
#     "PrimaryContainer": {
#         "Image": "763104351884.dkr.ecr.us-east-1.amazonaws.com/huggingface-pytorch-inference:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04",
#         "Environment": {
#             "SAGEMAKER_PROGRAM": "inference.py",
#             "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code",
#             "SAGEMAKER_CONTAINER_LOG_LEVEL": "20",
#             "SAGEMAKER_REGION": "us-east-1"
#         },
#         "ModelDataUrl": "s3://sagemaker-us-east-1-119174016168/sagemaker-jumpstart-2023-02-14-18-06-17-408/model.tar.gz"
#     },
#     "Tags": [
#         {
#             "Key": "aws-jumpstart-training-model-uri",
#             "Value": "s3://jumpstart-cache-prod-us-east-1/stabilityai-training/train-model-txt2img-stabilityai-stable-diffusion-v2-1-base.tar.gz"
#         },
#         {
#             "Key": "aws-jumpstart-training-script-uri",
#             "Value": "s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/transfer_learning/txt2img/v1.0.0/sourcedir.tar.gz"
#         },
#         {
#             "Key": "aws-jumpstart-inference-script-uri",
#             "Value": "s3://jumpstart-cache-prod-us-east-1/source-directory-tarballs/stabilityai/inference/txt2img/v1.2.1/sourcedir.tar.gz"
#         }
#     ]
# }
# Creating endpoint-config with name js-ep-20230214180617
# Creating endpoint with name js-ep-20230214180617
# ---------!CPU times: user 6min 27s, sys: 1min 2s, total: 7min 29s
# Wall time: 12min 47s

# %% [markdown]
# #### VII. Invoke the endpoint for inference using Predictor

# %%
prompt = 'riobugger cat in a space suit'

# %%
prompt = json.dumps(prompt).encode('utf-8')

# %%
MIME_INFO = {'ContentType': 'application/x-text', 
             'Accept': 'application/json'}

# %%
# %%time

response = predictor.predict(prompt, MIME_INFO)
# Out:
# CPU times: user 24.8 ms, sys: 5.62 ms, total: 30.4 ms
# Wall time: 26.3 s

# %%
response = json.loads(response)
img = response['generated_image']
prompt = response['prompt']

# %%
plt.figure(figsize=(12, 12))
plt.imshow(np.array(img))
plt.axis('off')
plt.title(prompt)
plt.show()

# %% [markdown]
# #### VIII. Invoke the endpoint for inference using SageMaker run-time client (Alternative)

# %%
prompt = 'riobugger cat animated and dressed as a police officer'

# %%
client = boto3.client('sagemaker-runtime')

# %%
# %%time

response = client.invoke_endpoint(EndpointName=endpoint_name, 
                                  Body=prompt, 
                                  ContentType='application/x-text')
# Out:
# CPU times: user 11.6 ms, sys: 7.56 ms, total: 19.2 ms
# Wall time: 26.3 s

# %%
response_body = json.loads(response['Body'].read().decode())
generated_image = response_body['generated_image']

# %%
plt.figure(figsize=(12, 12))
plt.imshow(np.array(generated_image))
plt.axis('off')
plt.title(prompt)
plt.show()
